# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

pd.set_option('display.float_format', lambda x: '%e' % x)
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
v_i = pd.read_fwf('dac_simulation_cascoded_igen.txt')
fig, ax = plt.subplots()
v_i.plot(y='i(viout)', ax = ax, title = 'Voltage To Current Characteristics')
plt.xlabel('bits')
plt.ylabel('Iout (A)')
plt.savefig("VtoI_plot.svg", format="svg")
print(len(v_i['i(viout)']))
# Out:
# 128

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

pd.set_option('display.float_format', lambda x: '%e' % x)

v_i1 = pd.read_fwf('~/DAC-VLSI/simulation_results/mc/dac_simulation_mc_lauren_1.txt')
v_i2 = pd.read_fwf('~/DAC-VLSI/simulation_results/mc/dac_simulation_mc_lauren_2.txt')
v_i3 = pd.read_fwf('~/DAC-VLSI/simulation_results/mc/dac_simulation_mc_lauren_3.txt')
v_i4 = pd.read_fwf('~/DAC-VLSI/simulation_results/mc/dac_simulation_mc_lauren_4.txt')
v_i5 = pd.read_fwf('~/DAC-VLSI/simulation_results/mc/dac_simulation_mc_lauren_5.txt')
v_i6 = pd.read_fwf('~/DAC-VLSI/simulation_results/mc/dac_simulation_mc_lauren_6.txt')
v_i7 = pd.read_fwf('~/DAC-VLSI/simulation_results/mc/dac_simulation_mc_lauren_7.txt')
v_i8 = pd.read_fwf('~/DAC-VLSI/simulation_results/mc/dac_simulation_mc_lauren_8.txt')
v_i9 = pd.read_fwf('~/DAC-VLSI/simulation_results/mc/dac_simulation_mc_lauren_9.txt')
v_i10 = pd.read_fwf('~/DAC-VLSI/simulation_results/mc/dac_simulation_mc_lauren_10.txt')
fig, ax = plt.subplots()
v_i1.plot(y='i(viout)', ax = ax, marker='o', fillstyle = 'none', title = 'Voltage To Current Characteristics')
v_i2.plot(y='i(viout)', ax = ax, marker='o', fillstyle = 'none',)
v_i3.plot(y='i(viout)', ax = ax, marker='o', fillstyle = 'none',)
v_i4.plot(y='i(viout)', ax = ax, marker='o', fillstyle = 'none',)
v_i5.plot(y='i(viout)', ax = ax, marker='o', fillstyle = 'none',)
v_i6.plot(y='i(viout)', ax = ax, marker='o', fillstyle = 'none',)
v_i7.plot(y='i(viout)', ax = ax, marker='o', fillstyle = 'none',)
v_i8.plot(y='i(viout)', ax = ax, marker='o', fillstyle = 'none',)
v_i9.plot(y='i(viout)', ax = ax, marker='o', fillstyle = 'none',)
v_i10.plot(y='i(viout)', ax = ax, marker='o', fillstyle = 'none',)
plt.xlabel('voltage')
plt.ylabel('Iout (A)')
plt.savefig("VtoI_plot.svg", format="svg")
